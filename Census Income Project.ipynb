# %%
# Importing required libraries

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Loda dataset

df= pd.read_csv('https://raw.githubusercontent.com/mohittomar2008/Census-Income-Project/main/census_income.csv')

# %%
# Dataset size
df.shape
# Out:
# (32560, 15)

# %%
print("Data have ",df.shape[0],'Rows and ',df.shape[1] ,'Columns')
# Out:
# Data have  32560 Rows and  15 Columns

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
df.tail()
# Out:
#        Age      Workclass  Fnlwgt    Education  Education_num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation Relationship    Race      Sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 32555             0             0              38   United-States   <=50K
# 32556             0             0              40   United-States    >50K
# 32557             0             0              40   United-States   <=50K
# 32558             0             0              20   United-States   <=50K
# 32559         15024             0              40   United-States    >50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# we have no null values, 
# 6  features are of Integer data types
# 9  features are of Catagorical data types

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32560.0      38.581634      13.640642     17.0      28.0
# Fnlwgt          32560.0  189781.814373  105549.764924  12285.0  117831.5
# Education_num   32560.0      10.080590       2.572709      1.0       9.0
# Capital_gain    32560.0    1077.615172    7385.402999      0.0       0.0
# Capital_loss    32560.0      87.306511     402.966116      0.0       0.0
# Hours_per_week  32560.0      40.437469      12.347618      1.0      40.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# Fnlwgt          178363.0  237054.5  1484705.0
# Education_num       10.0      12.0       16.0
# Capital_gain         0.0       0.0    99999.0
# Capital_loss         0.0       0.0     4356.0
# Hours_per_week      40.0      45.0       99.0

# %% [raw]
# # Conclusion:
#
# Captal_gain  and Capital_loss have completely right skewed data

# %% [markdown]
# # Null Values

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# Null Vlaues in %

(df.isnull().sum()/df.shape[0])*100
# Out:
# Age               0.0
# Workclass         0.0
# Fnlwgt            0.0
# Education         0.0
# Education_num     0.0
# Marital_status    0.0
# Occupation        0.0
# Relationship      0.0
# Race              0.0
# Sex               0.0
# Capital_gain      0.0
# Capital_loss      0.0
# Hours_per_week    0.0
# Native_country    0.0
# Income            0.0
# dtype: float64

# %%
# No Null Values present in the data

# %%
# Check unique values:
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
for i in df.columns:
    print( i ,'have unique values = ',df[i].unique(),'\n')
# Out:
# Age have unique values =  [50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 39 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
# Workclass have unique values =  [' Self-emp-not-inc' ' Private' ' State-gov' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
# Fnlwgt have unique values =  [ 83311 215646 234721 ...  34066  84661 257302]
#
# Education have unique values =  [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
#
# Education_num have unique values =  [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
# Marital_status have unique values =  [' Married-civ-spouse' ' Divorced' ' Married-spouse-absent'
#  ' Never-married' ' Separated' ' Married-AF-spouse' ' Widowed']
#
# Occupation have unique values =  [' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Adm-clerical' ' Sales' ' Craft-repair'
#  ' Transport-moving' ' Farming-fishing' ' Machine-op-inspct'
#  ' Tech-support' ' ?' ' Protective-serv' ' Armed-Forces'
#  ' Priv-house-serv']
#
# Relationship have unique values =  [' Husband' ' Not-in-family' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
#
# Race have unique values =  [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
#
# Sex have unique values =  [' Male' ' Female']
#
# Capital_gain have unique values =  [    0 14084  5178  5013  2407 14344 15024  7688 34095  4064  4386  7298
#   1409  3674  1055  3464  2050  2176  2174   594 20051  6849  4101  1111
#   8614  3411  2597 25236  4650  9386  2463  3103 10605  2964  3325  2580
#   3471  4865 99999  6514  1471  2329  2105  2885 25124 10520  2202  2961
#  27828  6767  2228  1506 13550  2635  5556  4787  3781  3137  3818  3942
#    914   401  2829  2977  4934  2062  2354  5455 15020  1424  3273 22040
#   4416  3908 10566   991  4931  1086  7430  6497   114  7896  2346  3418
#   3432  2907  1151  2414  2290 15831 41310  4508  2538  3456  6418  1848
#   3887  5721  9562  1455  2036  1831 11678  2936  2993  7443  6360  1797
#   1173  4687  6723  2009  6097  2653  1639 18481  7978  2387  5060]
#
# Capital_loss have unique values =  [   0 2042 1408 1902 1573 1887 1719 1762 1564 2179 1816 1980 1977 1876
#  1340 2206 1741 1485 2339 2415 1380 1721 2051 2377 1669 2352 1672  653
#  2392 1504 2001 1590 1651 1628 1848 1740 2002 1579 2258 1602  419 2547
#  2174 2205 1726 2444 1138 2238  625  213 1539  880 1668 1092 1594 3004
#  2231 1844  810 2824 2559 2057 1974  974 2149 1825 1735 1258 2129 2603
#  2282  323 4356 2246 1617 1648 2489 3770 1755 3683 2267 2080 2457  155
#  3900 2201 1944 2467 2163 2754 2472 1411]
#
# Hours_per_week have unique values =  [13 40 16 45 50 80 30 35 60 20 52 44 15 25 38 43 55 48 58 32 70  2 22 56
#  41 28 36 24 46 42 12 65  1 10 34 75 98 33 54  8  6 64 19 18 72  5  9 47
#  37 21 26 14  4 59  7 99 53 39 62 57 78 90 66 11 49 84  3 17 68 27 85 31
#  51 77 63 23 87 88 73 89 97 94 29 96 67 82 86 91 81 76 92 61 74 95]
#
# Native_country have unique values =  [' United-States' ' Cuba' ' Jamaica' ' India' ' ?' ' Mexico' ' South'
#  ' Puerto-Rico' ' Honduras' ' England' ' Canada' ' Germany' ' Iran'
#  ' Philippines' ' Italy' ' Poland' ' Columbia' ' Cambodia' ' Thailand'
#  ' Ecuador' ' Laos' ' Taiwan' ' Haiti' ' Portugal' ' Dominican-Republic'
#  ' El-Salvador' ' France' ' Guatemala' ' China' ' Japan' ' Yugoslavia'
#  ' Peru' ' Outlying-US(Guam-USVI-etc)' ' Scotland' ' Trinadad&Tobago'
#  ' Greece' ' Nicaragua' ' Vietnam' ' Hong' ' Ireland' ' Hungary'
#  ' Holand-Netherlands']
#
# Income have unique values =  [' <=50K' ' >50K']

# %%
# Workclass  , Occupation , Native_country  have some null values in form of ' ?' --> "whitespace ?""

# %%
df.isin([' ?']).sum()
# Out:
# Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_num        0
# Marital_status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hours_per_week       0
# Native_country     583
# Income               0
# dtype: int64

# %%
# % withcolumns

(df.isin([' ?']).sum()/df.shape[0])*100
# Out:
# Age               0.000000
# Workclass         5.638821
# Fnlwgt            0.000000
# Education         0.000000
# Education_num     0.000000
# Marital_status    0.000000
# Occupation        5.660319
# Relationship      0.000000
# Race              0.000000
# Sex               0.000000
# Capital_gain      0.000000
# Capital_loss      0.000000
# Hours_per_week    0.000000
# Native_country    1.790541
# Income            0.000000
# dtype: float64

# %% [raw]
# Workclass have 5.6% null values
# Occupation have 5.66% null values
# Native country have 1.7% null values
#
# We have to handle them

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %% [markdown]
# # EDA

# %%
# Target Variable  : Income

# %%
df['Income'].value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
# This is imbalanced data, we have to balanced this as well

# %%
sns.countplot(df['Income'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
# Age

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.histplot(df['Age'])
plt.title('Age distribution')
# Out:
# Text(0.5, 1.0, 'Age distribution')

# %%
# Age data is right skewed

# %%
df['Workclass'].unique()
# Out:
# array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['Workclass'])
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
plt.pie(df['Workclass'].value_counts().values,labels=df['Workclass'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1558c31bd00>,
#   <matplotlib.patches.Wedge at 0x1558b8493a0>,
#   <matplotlib.patches.Wedge at 0x1558b849ac0>,
#   <matplotlib.patches.Wedge at 0x1558b849fd0>,
#   <matplotlib.patches.Wedge at 0x1558b840460>,
#   <matplotlib.patches.Wedge at 0x1558b840550>,
#   <matplotlib.patches.Wedge at 0x1558c1848b0>,
#   <matplotlib.patches.Wedge at 0x1558c184ee0>,
#   <matplotlib.patches.Wedge at 0x1558c804790>],
#  [Text(-0.6382930911712503, 0.8958693709258343, ' Private'),
#   Text(-0.09614160158809627, -1.0957904874765414, ' Self-emp-not-inc'),
#   Text(0.3870941794944444, -1.029639789538809, ' Local-gov'),
#   Text(0.740659051351343, -0.8132798839583633, ' ?'),
#   Text(0.9491955757802714, -0.5559026523764384, ' State-gov'),
#   Text(1.0518455289897355, -0.3219021328669688, ' Self-emp-inc'),
#   Text(1.0948632169908754, -0.10618161837338717, ' Federal-gov'),
#   Text(1.099995985562683, -0.0029718253619576878, ' Without-pay'),
#   Text(1.0999997490710822, -0.0007429963368566515, ' Never-worked')],
#  [Text(-0.3481598679115911, 0.48865602050500045, '69.71%'),
#   Text(-0.052440873593507055, -0.5977039022599315, '7.80%'),
#   Text(0.21114227972424238, -0.5616217033848049, '6.43%'),
#   Text(0.4039958461916416, -0.44360720943183446, '5.64%'),
#   Text(0.5177430413346934, -0.3032196285689664, '3.98%'),
#   Text(0.5737339249034921, -0.17558298156380112, '3.43%'),
#   Text(0.5971981183586592, -0.05791724638548391, '2.95%'),
#   Text(0.5999978103069179, -0.0016209956519769204, '0.04%'),
#   Text(0.5999998631296811, -0.00040527072919453716, '0.02%')])

# %% [raw]
#  69.71% are doing private Job / Majority of them
#
# 7.80% are self emploid
# 6.43% are Local Govt
#
# 5.64%  is missing with ?
#
# .04% are without Pay
# .02% never pworked

# %%
# Education

# %%
df['Education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,8))
sns.countplot(df['Education'],order=df['Education'].value_counts().index)
plt.title('Education chart')
plt.xlabel('Education')
plt.ylabel('No of peoples')
# Out:
# Text(0, 0.5, 'No of peoples')

# %%
From the Sample,
MAximum peoples have done HS-grad, then Some-collegue, Bachelors
# Out:
#   File "C:\Users\BANKOF~1\AppData\Local\Temp/ipykernel_4348/2881534074.py", line 1
#     From the Sample,
#          ^
# SyntaxError: invalid syntax

# %% [raw]
# # Education_num

# %%
df['Education_num'].unique()

# %%
sns.countplot(df['Education_num'])
plt.title('Education years')
plt.ylabel('Count of peoples')

# %%
# Maximum peoples have taken 9years education and then 10 years

# %%
df.columns

# %%
# Marital_status

# %%
df['Marital_status'].unique()
# Out:
# array([' Married-civ-spouse', ' Divorced', ' Married-spouse-absent',
#        ' Never-married', ' Separated', ' Married-AF-spouse', ' Widowed'],
#       dtype=object)

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['Marital_status'],order=df['Marital_status'].value_counts().index)
plt.title('Marrige Distribution')
# Out:
# Text(0.5, 1.0, 'Marrige Distribution')

# %%
plt.figure(figsize=(12,8))
plt.pie(df['Marital_status'].value_counts().values,labels=df['Marital_status'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1558a4ea670>,
#   <matplotlib.patches.Wedge at 0x1558a4eadf0>,
#   <matplotlib.patches.Wedge at 0x1558a4f7550>,
#   <matplotlib.patches.Wedge at 0x1558a4f7c70>,
#   <matplotlib.patches.Wedge at 0x1558b4943d0>,
#   <matplotlib.patches.Wedge at 0x1558b494af0>,
#   <matplotlib.patches.Wedge at 0x1558b49c250>],
#  [Text(0.13803501708558066, 1.0913048767682585, ' Married-civ-spouse'),
#   Text(-0.7827548151178912, -0.7728485617569305, ' Never-married'),
#   Text(0.6810034412960271, -0.8638485474566527, ' Divorced'),
#   Text(1.0233080239964072, -0.40353523764916543, ' Separated'),
#   Text(1.082048081689935, -0.1979190463576769, ' Widowed'),
#   Text(1.0988978136033434, -0.04923002394669188, ' Married-spouse-absent'),
#   Text(1.0999972916242746, -0.002440987353635856, ' Married-AF-spouse')],
#  [Text(0.07529182750122582, 0.5952572055099591, '46.00%'),
#   Text(-0.4269571718824861, -0.4215537609583257, '32.81%'),
#   Text(0.37145642252510563, -0.4711901167945378, '13.65%'),
#   Text(0.5581680130889494, -0.22011012962681747, '3.15%'),
#   Text(0.5902080445581462, -0.10795584346782375, '3.05%'),
#   Text(0.5993988074200054, -0.026852740334559207, '1.28%'),
#   Text(0.5999985227041498, -0.0013314476474377396, '0.07%')])

# %% [raw]
# Conclude:
#     46% are married-civ-spouse
#
#
#     32.18% never married

# %%
# Occupation|

# %%
df['Occupation'].unique()
# Out:
# array([' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty',
#        ' Other-service', ' Adm-clerical', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Occupation'], order=df['Occupation'].value_counts().index)
plt.title('Occupation Graph')
plt.ylabel('Peoples count')
# Out:
# Text(0, 0.5, 'Peoples count')

# %%
# Relationship

# %%
df['Relationship'].unique()
# Out:
# array([' Husband', ' Not-in-family', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Relationship'], order=df['Relationship'].value_counts().index)
plt.title('Relationship Graph',fontdict={'fontname':'monospace','fontsize':20})
plt.ylabel('Peoples count')
# Out:
# Text(0, 0.5, 'Peoples count')

# %%
# Race

# %%
sns.countplot(df['Race'])
# Out:
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %%
df['Race'].value_counts()
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64

# %% [raw]
# # Sex

# %%
sns.countplot(df['Sex'])
plt.title('Sex Distribution',fontdict={'fontname':'monospace','fontsize':15})
plt.ylabel('People counts')
# Out:
# Text(0, 0.5, 'People counts')

# %%
# Capital_gain

# %%
sns.distplot(df['Capital_gain'])
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Density'>

# %%
# right skewed data

# %%
#Capital_loss

# %%
sns.distplot(df['Capital_loss'])
# Out:
# <AxesSubplot:xlabel='Capital_loss', ylabel='Density'>

# %%
# Right skewed data

# %%
# Hours_per_week

# %%
df['Hours_per_week'].unique()
# Out:
# array([13, 40, 16, 45, 50, 80, 30, 35, 60, 20, 52, 44, 15, 25, 38, 43, 55,
#        48, 58, 32, 70,  2, 22, 56, 41, 28, 36, 24, 46, 42, 12, 65,  1, 10,
#        34, 75, 98, 33, 54,  8,  6, 64, 19, 18, 72,  5,  9, 47, 37, 21, 26,
#        14,  4, 59,  7, 99, 53, 39, 62, 57, 78, 90, 66, 11, 49, 84,  3, 17,
#        68, 27, 85, 31, 51, 77, 63, 23, 87, 88, 73, 89, 97, 94, 29, 96, 67,
#        82, 86, 91, 81, 76, 92, 61, 74, 95], dtype=int64)

# %%
sns.countplot(df['Hours_per_week'])
# Out:
# <AxesSubplot:xlabel='Hours_per_week', ylabel='count'>

# %%
hours=df['Hours_per_week'].value_counts().head(10)
hours
# Out:
# 40    15216
# 50     2819
# 45     1824
# 60     1475
# 35     1297
# 20     1224
# 30     1149
# 55      694
# 25      674
# 48      517
# Name: Hours_per_week, dtype: int64

# %%
sns.barplot(hours.index,hours.values,order=hours.index)
plt.title('Distribution of hours_per_week')
plt.ylabel('Peoples counts')
plt.xlabel('working hours')
# Out:
# Text(0.5, 0, 'working hours')

# %% [raw]
# Mostly peoples working 40hrs per week

# %% [markdown]
# # Bivarient nalysis

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Age'])
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Age'],hue=df['Income'])
plt.title('Age vs Income Distribution',fontdict={'fontsize':30})
# Out:
# Text(0.5, 1.0, 'Age vs Income Distribution')

# %%
# More Peoples between 36 years to 47 years have earned more than 50K
# Peoples started to earn at age 17, from 17 to 41 majority earn below 50k

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Workclass'],hue='Income', data=df)
plt.title(' Distribution of Income across WorkClass',fontdict={'fontsize':25})
# Out:
# Text(0.5, 1.0, ' Distribution of Income across WorkClass')

# %%
# In wvery woork class, most people argeeting income <50k, However selfwmploid peoples are able to earn more than >50k

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Education'],hue='Income', data=df)
plt.title(' Distribution of Income across Education',fontdict={'fontsize':25})
# Out:
# Text(0.5, 1.0, ' Distribution of Income across Education')

# %%
# More persons in Doctorate and Prof-School qualified persons got more than >50K

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Education_num'],hue='Income', data=df)
plt.title(' Distribution of Income across Education_num',fontdict={'fontsize':25})
# Out:
# Text(0.5, 1.0, ' Distribution of Income across Education_num')

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Marital_status'],hue='Income', data=df)
plt.title(' Distribution of Income across Marital_status',fontdict={'fontsize':25})
# Out:
# Text(0.5, 1.0, ' Distribution of Income across Marital_status')

# %%
plt.style.use('bmh')
plt.figure(figsize=(20,8))
sns.countplot(df['Race'],hue='Income', data=df)
plt.title(' Distribution of Income across Race',fontdict={'fontsize':25})
# Out:
# Text(0.5, 1.0, ' Distribution of Income across Race')

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Sex'],hue='Income', data=df)
plt.title(' Distribution of Income Sex',fontdict={'fontsize':25})
# Out:
# Text(0.5, 1.0, ' Distribution of Income Sex')

# %%
sns.scatterplot('Age','Hours_per_week',hue='Income', data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Hours_per_week'>

# %%
# After 70yr age, Mostly peoples works toll 60hrs per week

# %% [raw]
# Final understanding,
#
# Most peroples are white, young, 9-10years educated, works 40hrs per week

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
# Lets analyse correelation with target variable

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
df['Income']=le.fit_transform(df['Income'])

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States       0
# 1             0             0              40   United-States       0
# 2             0             0              40   United-States       0
# 3             0             0              40            Cuba       0
# 4             0             0              40   United-States       0

# %%
# Multivarient Analysis

# %%
df.corr()
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
# Income          0.234039 -0.009481       0.335182      0.223333      0.150523
#
#                 Hours_per_week    Income
# Age                   0.068756  0.234039
# Fnlwgt               -0.018770 -0.009481
# Education_num         0.148127  0.335182
# Capital_gain          0.078409  0.223333
# Capital_loss          0.054256  0.150523
# Hours_per_week        1.000000  0.229690
# Income                0.229690  1.000000

# %%
# Correlation with target variablessns.heatmap(df.corr(),annot=True,linecolor='white',linewidths=.25)

# %%
# Correlation with target variabel
# Age ahs correlation with income  .23
# Education_num  has correlation .34
# Capital gain has correlation .22
# Hours_per_week has correlation .23


# Final_Weight have low correlation with target feature = -.0095, its very very low

# %%
sns.pairplot(df)

# %% [markdown]
# # HAndle msing values

# %%
# here missing values are by ' ?' in categorical fetures,

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df[['Workclass','Occupation','Native_country']]
# Out:
#                Workclass          Occupation  Native_country
# 0       Self-emp-not-inc     Exec-managerial   United-States
# 1                Private   Handlers-cleaners   United-States
# 2                Private   Handlers-cleaners   United-States
# 3                Private      Prof-specialty            Cuba
# 4                Private     Exec-managerial   United-States
# ...                  ...                 ...             ...
# 32555            Private        Tech-support   United-States
# 32556            Private   Machine-op-inspct   United-States
# 32557            Private        Adm-clerical   United-States
# 32558            Private        Adm-clerical   United-States
# 32559       Self-emp-inc     Exec-managerial   United-States
#
# [32560 rows x 3 columns]

# %%
df['Workclass'].unique()
# Out:
# array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
# Mode replacement

# %%
df['Workclass'].mode()
# Out:
# 0     Private
# dtype: object

# %%
df['Workclass'].mode()[0]
# Out:
# ' Private'

# %%
# replace ? with Nan
df=df.replace(' ?',np.nan)

# %%
for i in ['Workclass','Occupation','Native_country']:
    df[i].fillna(df[i].mode()[0], inplace=True)

# %%
df.isin([' ?']).sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
num=df.select_dtypes(np.number)
num
# Out:
#        Age  Fnlwgt  Education_num  Capital_gain  Capital_loss  Hours_per_week  \
# 0       50   83311             13             0             0              13
# 1       38  215646              9             0             0              40
# 2       53  234721              7             0             0              40
# 3       28  338409             13             0             0              40
# 4       37  284582             14             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32555   27  257302             12             0             0              38
# 32556   40  154374              9             0             0              40
# 32557   58  151910              9             0             0              40
# 32558   22  201490              9             0             0              20
# 32559   52  287927              9         15024             0              40
#
#        Income
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 32555       0
# 32556       1
# 32557       0
# 32558       0
# 32559       1
#
# [32560 rows x 7 columns]

# %%
for i in num:
    sns.histplot(df[i])
    plt.show()

# %% [markdown]
# # Label Encoding for categorical features

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
for i in df.columns:
    if df[i].dtypes =='object':
        le=LabelEncoder()
        df[i]= le.fit_transform(df[i])

# %%
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          5   83311          9             13               2
# 1       38          3  215646         11              9               0
# 2       53          3  234721          1              7               2
# 3       28          3  338409          9             13               2
# 4       37          3  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          3  257302          7             12               2
# 32556   40          3  154374         11              9               2
# 32557   58          3  151910         11              9               6
# 32558   22          3  201490         11              9               4
# 32559   52          4  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0               3             0     4    1             0             0
# 1               5             1     4    1             0             0
# 2               5             0     2    1             0             0
# 3               9             5     2    0             0             0
# 4               3             5     4    0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 32555          12             5     4    0             0             0
# 32556           6             0     4    1             0             0
# 32557           0             4     4    0             0             0
# 32558           0             3     4    1             0             0
# 32559           3             5     4    0         15024             0
#
#        Hours_per_week  Native_country  Income
# 0                  13              38       0
# 1                  40              38       0
# 2                  40              38       0
# 3                  40               4       0
# 4                  40              38       0
# ...               ...             ...     ...
# 32555              38              38       0
# 32556              40              38       1
# 32557              40              38       0
# 32558              20              38       0
# 32559              40              38       1
#
# [32560 rows x 15 columns]

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# Correlation after encoding with Target variable

# %%
# Few features are  very low correlated with target variable,

# %% [markdown]
# # Split  independent and dependent features

# %%
X=df.drop('Income', axis=1)
Y=df['Income']

# %%
X.shape , Y.shape
# Out:
# ((32560, 14), (32560,))

# %% [markdown]
# # Extra Tree Classifier for Feature Selection

# %%
from sklearn.ensemble import ExtraTreesClassifier
select= ExtraTreesClassifier()
select.fit(X,Y)
# Out:
# ExtraTreesClassifier()

# %%
add=select.feature_importances_

# %%
for index,feature_imp in enumerate(select.feature_importances_):
    print(index , feature_imp)
# Out:
# 0 0.15780946065970025
# 1 0.04185710654580669
# 2 0.1676208308547155
# 3 0.037400126679672845
# 4 0.08797038557888306
# 5 0.07615710324958781
# 6 0.07304089678401038
# 7 0.0880006301395207
# 8 0.014722552230045215
# 9 0.028727749549956674
# 10 0.08850262245624366
# 11 0.027644360940345
# 12 0.09521267868031585
# 13 0.015333495651196379

# %%
imp_feature=pd.DataFrame()
imp_feature['Feature']= X.columns
imp_feature['Values']=select.feature_importances_

# %%
imp_feature.sort_values('Values',ascending=False)
# Out:
#            Feature    Values
# 2           Fnlwgt  0.167621
# 0              Age  0.157809
# 12  Hours_per_week  0.095213
# 10    Capital_gain  0.088503
# 7     Relationship  0.088001
# 4    Education_num  0.087970
# 5   Marital_status  0.076157
# 6       Occupation  0.073041
# 1        Workclass  0.041857
# 3        Education  0.037400
# 9              Sex  0.028728
# 11    Capital_loss  0.027644
# 13  Native_country  0.015333
# 8             Race  0.014723

# %%
16.7+15.7+9.5+8.8+8.8+8.7+7.6+7.3+4.1+3.7+2.8+2.7
# Out:
# 96.39999999999999

# %%
# 12 features explanes the variation 96.3%, we can drop last 2 features

# %%
X=X.drop(['Native_country','Race'], axis=1)

# %%
X.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          5   83311          9             13               2
# 1   38          3  215646         11              9               0
# 2   53          3  234721          1              7               2
# 3   28          3  338409          9             13               2
# 4   37          3  284582         12             14               2
#
#    Occupation  Relationship  Sex  Capital_gain  Capital_loss  Hours_per_week
# 0           3             0    1             0             0              13
# 1           5             1    1             0             0              40
# 2           5             0    1             0             0              40
# 3           9             5    0             0             0              40
# 4           3             5    0             0             0              40

# %% [markdown]
# # Scaling()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X=sc.fit_transform(X)

# %%
pd.DataFrame(X)
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.837097  1.721336 -1.008742 -0.335443  1.134779 -0.406183 -0.790156
# 1     -0.042640 -0.085223  0.245046  0.181319 -0.420027 -1.734026 -0.286703
# 2      1.057031 -0.085223  0.425770 -2.402489 -1.197429 -0.406183 -0.286703
# 3     -0.775755 -0.085223  1.408146 -0.335443  1.134779 -0.406183  0.720204
# 4     -0.115952 -0.085223  0.898170  0.439700  1.523480 -0.406183 -0.790156
# ...         ...       ...       ...       ...       ...       ...       ...
# 32555 -0.849066 -0.085223  0.639710 -0.852204  0.746077 -0.406183  1.475385
# 32556  0.103982 -0.085223 -0.335466  0.181319 -0.420027 -0.406183 -0.034976
# 32557  1.423589 -0.085223 -0.358811  0.181319 -0.420027  2.249503 -1.545336
# 32558 -1.215624 -0.085223  0.110927  0.181319 -0.420027  0.921660 -1.545336
# 32559  0.983720  0.818056  0.929862  0.181319 -0.420027 -0.406183 -0.790156
#
#              7         8         9         10        11
# 0     -0.900177  0.703087 -0.145914 -0.216663 -2.222120
# 1     -0.277810  0.703087 -0.145914 -0.216663 -0.035430
# 2     -0.900177  0.703087 -0.145914 -0.216663 -0.035430
# 3      2.211658 -1.422298 -0.145914 -0.216663 -0.035430
# 4      2.211658 -1.422298 -0.145914 -0.216663 -0.035430
# ...         ...       ...       ...       ...       ...
# 32555  2.211658 -1.422298 -0.145914 -0.216663 -0.197407
# 32556 -0.900177  0.703087 -0.145914 -0.216663 -0.035430
# 32557  1.589291 -1.422298 -0.145914 -0.216663 -0.035430
# 32558  0.966924  0.703087 -0.145914 -0.216663 -1.655200
# 32559  2.211658 -1.422298  1.888401 -0.216663 -0.035430
#
# [32560 rows x 12 columns]

# %% [markdown]
# # Balance Dataset

# %%
from imblearn.over_sampling import SMOTE
smt=SMOTE()

# %%
Y.value_counts()*100
# Out:
# 0    2471900
# 1     784100
# Name: Income, dtype: int64

# %%
Y.value_counts(normalize=True)*100
# Out:
# 0    75.918305
# 1    24.081695
# Name: Income, dtype: float64

# %%
 balanced_X,balanced_Y=smt.fit_resample(X,Y)

# %%
balanced_X.shape  , balanced_Y.shape
# Out:
# ((49438, 12), (49438,))

# %%
balanced_Y.value_counts(normalize=True)*100
# Out:
# 0    50.0
# 1    50.0
# Name: Income, dtype: float64

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score

# %%
#Try to  Find best random state

# %%
# FInd best Random_state

maxaccu=0
maxRS=0

for i in range(0,200):
    x_train,x_test,y_train,y_test= train_test_split(balanced_X,balanced_Y,random_state=i,test_size=.20)
    LR= LogisticRegression()
    LR.fit(x_train,y_train)
    pred= LR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxRS=i
print("Best accuracy is ",maxaccu,"on Random State =",maxRS)
# Out:
# Best accuracy is  0.7806432038834952 on Random State = 23

# %%
# Use, Random state= 23

# %%
x_train,x_test,y_train,y_test= train_test_split(balanced_X,balanced_Y,random_state=23,test_size=.3)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
LR_model= LogisticRegression()
RD_model= RidgeClassifier()
DT_model= DecisionTreeClassifier()
SV_model= SVC()
KNR_model= KNeighborsClassifier()
RFR_model= RandomForestClassifier()
XGB_model= XGBClassifier()
SGH_model= SGDClassifier()
Bag_model=BaggingClassifier()
ADA_model=AdaBoostClassifier()
GB_model= GradientBoostingClassifier()

model=[LR_model,RD_model,DT_model,SV_model,KNR_model,RFR_model,XGB_model,SGH_model,Bag_model,ADA_model,GB_model ]

# %%
for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    pred= m.predict(x_test)
    print('Accuracy_Score of ',m, 'is', accuracy_score(y_test,pred)*100)
    print("F1 SCore                ", f1_score(y_test,pred)*100)
    print('Confusion Matrix of ',m,' is \n', confusion_matrix(y_test,pred) )
    print(classification_report(y_test,pred))
    print('*'*50)
# Out:
# Accuracy_Score of  LogisticRegression() is 77.78451995685005
# F1 SCore                 77.73498209338469
# Confusion Matrix of  LogisticRegression()  is
#  [[5785 1667]
#  [1628 5752]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78      7452
#            1       0.78      0.78      0.78      7380
#
#     accuracy                           0.78     14832
#    macro avg       0.78      0.78      0.78     14832
# weighted avg       0.78      0.78      0.78     14832
#
# **************************************************
# Accuracy_Score of  RidgeClassifier() is 76.34169363538295
# F1 SCore                 76.90079652425779
# Confusion Matrix of  RidgeClassifier()  is
#  [[5482 1970]
#  [1539 5841]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76      7452
#            1       0.75      0.79      0.77      7380
#
#     accuracy                           0.76     14832
#    macro avg       0.76      0.76      0.76     14832
# weighted avg       0.76      0.76      0.76     14832
#
# **************************************************
# Accuracy_Score of  DecisionTreeClassifier() is 85.38295577130529
# F1 SCore                 85.35135135135134
# Confusion Matrix of  DecisionTreeClassifier()  is
#  [[6348 1104]
#  [1064 6316]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.85      7452
#            1       0.85      0.86      0.85      7380
#
#     accuracy                           0.85     14832
#    macro avg       0.85      0.85      0.85     14832
# weighted avg       0.85      0.85      0.85     14832
#
# **************************************************
# Accuracy_Score of  SVC() is 82.97599784250271
# F1 SCore                 84.00987904502564
# Confusion Matrix of  SVC()  is
#  [[5674 1778]
#  [ 747 6633]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.76      0.82      7452
#            1       0.79      0.90      0.84      7380
#
#     accuracy                           0.83     14832
#    macro avg       0.84      0.83      0.83     14832
# weighted avg       0.84      0.83      0.83     14832
#
# **************************************************
# Accuracy_Score of  KNeighborsClassifier() is 85.61218985976268
# F1 SCore                 86.50904033379695
# Confusion Matrix of  KNeighborsClassifier()  is
#  [[5856 1596]
#  [ 538 6842]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85      7452
#            1       0.81      0.93      0.87      7380
#
#     accuracy                           0.86     14832
#    macro avg       0.86      0.86      0.86     14832
# weighted avg       0.86      0.86      0.86     14832
#
# **************************************************
# Accuracy_Score of  RandomForestClassifier() is 89.56310679611651
# F1 SCore                 89.6524064171123
# Confusion Matrix of  RandomForestClassifier()  is
#  [[6578  874]
#  [ 674 6706]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89      7452
#            1       0.88      0.91      0.90      7380
#
#     accuracy                           0.90     14832
#    macro avg       0.90      0.90      0.90     14832
# weighted avg       0.90      0.90      0.90     14832
#
# **************************************************
# [19:46:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy_Score of  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None) is 90.70253505933118
# F1 SCore                 90.66034541144599
# Confusion Matrix of  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)  is
#  [[6760  692]
#  [ 687 6693]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91      7452
#            1       0.91      0.91      0.91      7380
#
#     accuracy                           0.91     14832
#    macro avg       0.91      0.91      0.91     14832
# weighted avg       0.91      0.91      0.91     14832
#
# **************************************************
# Accuracy_Score of  SGDClassifier() is 77.66316073354909
# F1 SCore                 78.21684528897363
# Confusion Matrix of  SGDClassifier()  is
#  [[5571 1881]
#  [1432 5948]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77      7452
#            1       0.76      0.81      0.78      7380
#
#     accuracy                           0.78     14832
#    macro avg       0.78      0.78      0.78     14832
# weighted avg       0.78      0.78      0.78     14832
#
# **************************************************
# Accuracy_Score of  BaggingClassifier() is 88.14050701186623
# F1 SCore                 87.9759382049354
# Confusion Matrix of  BaggingClassifier()  is
#  [[6638  814]
#  [ 945 6435]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88      7452
#            1       0.89      0.87      0.88      7380
#
#     accuracy                           0.88     14832
#    macro avg       0.88      0.88      0.88     14832
# weighted avg       0.88      0.88      0.88     14832
#
# **************************************************
# Accuracy_Score of  AdaBoostClassifier() is 84.93122977346277
# F1 SCore                 85.09900660044003
# Confusion Matrix of  AdaBoostClassifier()  is
#  [[6215 1237]
#  [ 998 6382]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85      7452
#            1       0.84      0.86      0.85      7380
#
#     accuracy                           0.85     14832
#    macro avg       0.85      0.85      0.85     14832
# weighted avg       0.85      0.85      0.85     14832
#
# **************************************************
# Accuracy_Score of  GradientBoostingClassifier() is 86.43473570658037
# F1 SCore                 86.80655737704917
# Confusion Matrix of  GradientBoostingClassifier()  is
#  [[6201 1251]
#  [ 761 6619]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      7452
#            1       0.84      0.90      0.87      7380
#
#     accuracy                           0.86     14832
#    macro avg       0.87      0.86      0.86     14832
# weighted avg       0.87      0.86      0.86     14832
#
# **************************************************

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in model:
    print('Accuracy_Score of ',i, 'is', accuracy_score(y_test,i.predict(x_test))*100)
    print("cross Validation accuracy score of ",i ," is ",cross_val_score(i,balanced_X,balanced_Y,cv=5, scoring='accuracy').mean()*100)
    print('*'*50)
# Out:
# Accuracy_Score of  LogisticRegression() is 77.78451995685005
# cross Validation accuracy score of  LogisticRegression()  is  77.04601806235706
# **************************************************
# Accuracy_Score of  RidgeClassifier() is 76.34169363538295
# cross Validation accuracy score of  RidgeClassifier()  is  75.7878732345406
# **************************************************
# Accuracy_Score of  DecisionTreeClassifier() is 85.38295577130529
# cross Validation accuracy score of  DecisionTreeClassifier()  is  85.07638519968197
# **************************************************
# Accuracy_Score of  SVC() is 82.97599784250271
# cross Validation accuracy score of  SVC()  is  83.26795826823691
# **************************************************
# Accuracy_Score of  KNeighborsClassifier() is 85.61218985976268
# cross Validation accuracy score of  KNeighborsClassifier()  is  86.1827395524115
# **************************************************
# Accuracy_Score of  RandomForestClassifier() is 89.56310679611651
# cross Validation accuracy score of  RandomForestClassifier()  is  89.82980617875194
# **************************************************
# Accuracy_Score of  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None) is 90.70253505933118
# [19:58:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:58:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:58:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:58:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:58:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# cross Validation accuracy score of  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)  is  89.1724895444739
# **************************************************
# Accuracy_Score of  SGDClassifier() is 77.66316073354909
# cross Validation accuracy score of  SGDClassifier()  is  76.5504271897032
# **************************************************
# Accuracy_Score of  BaggingClassifier() is 88.14050701186623
# cross Validation accuracy score of  BaggingClassifier()  is  88.05589938145708
# **************************************************
# Accuracy_Score of  AdaBoostClassifier() is 84.93122977346277
# cross Validation accuracy score of  AdaBoostClassifier()  is  84.75267713675863
# **************************************************
# Accuracy_Score of  GradientBoostingClassifier() is 86.43473570658037
# cross Validation accuracy score of  GradientBoostingClassifier()  is  86.04522876301559
# **************************************************

# %% [raw]
# Accuracy_Score of  RandomForestClassifier() is 89.56310679611651
# cross Validation accuracy score of  RandomForestClassifier()  is  89.82980617875194
#
# Random Forest having least difference between

# %% [markdown]
# # Hypertuning

# %%
n_estimator= [200, 400, 600, 800, 1000]  # no of tree in Random forest, default is 100
max_features= ['auto','sqrt','log2']  # mini no of features to create Decission Tree
max_depth=[10, 64, 118, 173, 227, 282, 336]  #  Max depth of decision tree
min_samples_split= [1,2,3]   # mini no of sample rerquired to split node
min_samples_leaf= [1,3,4,6,7,9]  #mini no of sample required at each leaf node

param_grid= {'n_estimators': n_estimator,
             'max_features':max_features,
             'max_depth':max_depth,
             'min_samples_split':min_samples_split,
             'min_samples_leaf':min_samples_leaf,
             }
param_grid
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000],
#  'max_features': ['auto', 'sqrt', 'log2'],
#  'max_depth': [10, 64, 118, 173, 227, 282, 336],
#  'min_samples_split': [1, 2, 3],
#  'min_samples_leaf': [1, 3, 4, 6, 7, 9]}

# %%
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV

# %%
random= RandomizedSearchCV(RFR_model,param_distributions=param_grid,cv=5,n_jobs=-1)
random.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#                    param_distributions={'max_depth': [10, 64, 118, 173, 227,
#                                                       282, 336],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 3, 4, 6, 7, 9],
#                                         'min_samples_split': [1, 2, 3],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000]})

# %%
random.best_estimator_
# Out:
# RandomForestClassifier(max_depth=227, min_samples_leaf=3, min_samples_split=3,
#                        n_estimators=400)

# %%
random.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 3,
#  'min_samples_leaf': 3,
#  'max_features': 'auto',
#  'max_depth': 227}

# %%
pred=random.best_estimator_.predict(x_test)
accuracy_score(y_test,pred)
# Out:
# 0.8846413160733549

# %% [raw]
# As per the help of Randomsearch cv result, creating another parameters

# %%
n_estimator= [350, 400, 450,500]  # no of tree in Random forest, default is 100
max_features= ['auto','sqrt','log2']  # mini no of features to create Decission Tree
max_depth=[180,200,220,240,260]  #  Max depth of decision tree
min_samples_split= [2,3,4]   # mini no of sample rerquired to split node
min_samples_leaf= [1,2,3,4]  #mini no of sample required at each leaf node

param_grid= {'n_estimators': n_estimator,
             'max_features':max_features,
             'max_depth':max_depth,
             'min_samples_split':min_samples_split,
             'min_samples_leaf':min_samples_leaf,
             }
param_grid
# Out:
# {'n_estimators': [350, 400, 450, 500],
#  'max_features': ['auto', 'sqrt', 'log2'],
#  'max_depth': [180, 200, 220, 240, 260],
#  'min_samples_split': [2, 3, 4],
#  'min_samples_leaf': [1, 2, 3, 4]}

# %%
grid= GridSearchCV(RFR_model,param_grid=param_grid,cv=5,n_jobs=-1)
grid.fit(x_train,y_train)
